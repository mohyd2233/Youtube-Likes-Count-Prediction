# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv(r"E:\Great Learning\4. Python (Module-2)\project\USvideos.csv")

# %%
df2 = pd.read_json(r"E:\Great Learning\4. Python (Module-2)\project\US_category_id.json")

# %%
df.drop(['description','thumbnail_link','tags'],axis=1,inplace=True)

# %%
df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
df['trending_date'] = pd.to_datetime(df['trending_date'],format='%y.%d.%m')

# %%
df['publish_year'] = df['publish_time'].dt.year

# %%
df['publish_month'] = df['publish_time'].dt.month_name()

# %%
title = [df2['items'][i]['snippet']['title'] for i in range(0,32)]

# %%
id = [df2['items'][i]['id'] for i in range(0,32)]

# %%
id_genre = pd.DataFrame({'category_id':id,'genre':title})

# %%
id_genre['category_id'] = id_genre['category_id'].astype(int)

# %%
df = pd.merge(df,id_genre,how='inner',on='category_id')

# %%
df = df.loc[:,['video_id','publish_time','publish_year', 'publish_month', 'trending_date', 'title', 'channel_title', 'views', 'likes', 'dislikes', 'comment_count',
       'comments_disabled', 'ratings_disabled', 'video_error_or_removed','category_id', 'genre']]

# %%
df.head(3)
# Out:
#       video_id              publish_time  publish_year publish_month
# 0  2kyS6SvSYSE 2017-11-13 17:13:01+00:00          2017      November  \
# 1  0mlNzVSJrT0 2017-04-21 06:47:32+00:00          2017         April
# 2  STI2fI7sKMo 2017-11-11 15:00:03+00:00          2017      November
#
#   trending_date                                              title
# 0    2017-11-14                 WE WANT TO TALK ABOUT OUR MARRIAGE  \
# 1    2017-11-14                               Me-O Cats Commercial
# 2    2017-11-14  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...
#
#         channel_title   views  likes  dislikes  comment_count
# 0        CaseyNeistat  748374  57527      2966          15954  \
# 1             Nobrand   98966   2486       184            532
# 2  Shawn Johnson East  321053   4451      1772            895
#
#    comments_disabled  ratings_disabled  video_error_or_removed  category_id
# 0              False             False                   False           22  \
# 1              False             False                   False           22
# 2              False             False                   False           22
#
#             genre
# 0  People & Blogs
# 1  People & Blogs
# 2  People & Blogs

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   publish_time            40949 non-null  object
#  2   publish_year            40949 non-null  int32
#  3   publish_month           40949 non-null  object
#  4   trending_date           40949 non-null  datetime64[ns]
#  5   title                   40949 non-null  object
#  6   channel_title           40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  comments_disabled       40949 non-null  bool
#  12  ratings_disabled        40949 non-null  bool
#  13  video_error_or_removed  40949 non-null  bool
#  14  category_id             40949 non-null  int64
#  15  genre                   40949 non-null  object
# dtypes: bool(3), datetime64[ns](1), int32(1), int64(5), object(6)
# memory usage: 4.0+ MB

# %%
df['publish_time'] = df['publish_time'].astype(str)

# %%
#string slicing in dataframes
df['publish_time'] = df['publish_time'].str[:10]

# %%
df = pd.concat([publish_date,df],axis=1)

# %%
df = df.loc[:,['video_id','publish_time','publish_year', 'publish_month', 'trending_date', 'title', 'channel_title', 'views', 'likes', 'dislikes', 'comment_count',
       'comments_disabled', 'ratings_disabled', 'video_error_or_removed','category_id', 'genre']]

# %%
df
# Out:
#           video_id publish_time  publish_year publish_month trending_date
# 0      2kyS6SvSYSE   2017-11-13          2017      November    2017-11-14  \
# 1      0mlNzVSJrT0   2017-04-21          2017         April    2017-11-14
# 2      STI2fI7sKMo   2017-11-11          2017      November    2017-11-14
# 3      KODzih-pYlU   2017-11-11          2017      November    2017-11-14
# 4      8mhTWqWlQzU   2017-11-11          2017      November    2017-11-14
# ...            ...          ...           ...           ...           ...
# 40944  V6ElE2xs48c   2018-05-10          2018           May    2018-06-02
# 40945  V6ElE2xs48c   2018-05-10          2018           May    2018-06-03
# 40946  V6ElE2xs48c   2018-05-10          2018           May    2018-06-04
# 40947  V6ElE2xs48c   2018-05-10          2018           May    2018-06-05
# 40948  V6ElE2xs48c   2018-05-10          2018           May    2018-06-06
#
#                                                    title       channel_title
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat  \
# 1                                   Me-O Cats Commercial             Nobrand
# 2      AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3      BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4          Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
# ...                                                  ...                 ...
# 40944       Game of Zones - S5:E5: The Isle of Van Gundy     Bleacher Report
# 40945       Game of Zones - S5:E5: The Isle of Van Gundy     Bleacher Report
# 40946       Game of Zones - S5:E5: The Isle of Van Gundy     Bleacher Report
# 40947       Game of Zones - S5:E5: The Isle of Van Gundy     Bleacher Report
# 40948       Game of Zones - S5:E5: The Isle of Van Gundy     Bleacher Report
#
#          views   likes  dislikes  comment_count  comments_disabled
# 0       748374   57527      2966          15954              False  \
# 1        98966    2486       184            532              False
# 2       321053    4451      1772            895              False
# 3       197062    7250       217            456              False
# 4      2744430  115426      1110           6541              False
# ...        ...     ...       ...            ...                ...
# 40944  1324482   22413       608           1644              False
# 40945  1332252   22461       610           1648              False
# 40946  1340039   22504       615           1648              False
# 40947  1345086   22542       615           1649              False
# 40948  1351321   22587       616           1649              False
#
#        ratings_disabled  video_error_or_removed  category_id           genre
# 0                 False                   False           22  People & Blogs
# 1                 False                   False           22  People & Blogs
# 2                 False                   False           22  People & Blogs
# 3                 False                   False           22  People & Blogs
# 4                 False                   False           22  People & Blogs
# ...                 ...                     ...          ...             ...
# 40944             False                   False           43           Shows
# 40945             False                   False           43           Shows
# 40946             False                   False           43           Shows
# 40947             False                   False           43           Shows
# 40948             False                   False           43           Shows
#
# [40949 rows x 16 columns]

# %%
df['genre'].unique()
# Out:
# array(['People & Blogs', 'Entertainment', 'Comedy',
#        'Science & Technology', 'Film & Animation', 'News & Politics',
#        'Sports', 'Music', 'Pets & Animals', 'Education', 'Howto & Style',
#        'Autos & Vehicles', 'Travel & Events', 'Gaming',
#        'Nonprofits & Activism', 'Shows'], dtype=object)

# %%
music = df.loc[(df['genre']=='Music')&(df['channel_title'].str.contains('childish',case=False))&(df['title'].str.contains('this is america',case=False)),['channel_title','title','genre','publish_month','publish_year','publish_time','trending_date','views']]

# %%
entertainment = df.loc[(df['genre']=='Entertainment')&(df['channel_title'].str.contains('the graham norton',case=False))&(df['title'].str.contains('jason momoa shows off',case=False)),['channel_title','title','genre','publish_month','publish_year','trending_date','views']]

# %%
nonprof = df.loc[(df['genre']=='Nonprofits & Activism')&(df['channel_title'].str.contains('logan paul vlogs',case=False))&(df['title'].str.contains('suicide:',case=False)),['channel_title','title','genre','publish_month','publish_year','trending_date','views']]

# %%
music.head()
# Out:
#              channel_title                                              title
# 30920  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...  \
# 30957  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 30998  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31038  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31084  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31123  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31192  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31225  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31261  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31298  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31332  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31367  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31406  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31441  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31479  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31519  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31560  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31605  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31647  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31685  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 31725  ChildishGambinoVEVO  Childish Gambino - This Is America (Official V...
# 
# 40863  Logan Paul Vlogs  Suicide: Be Here Tomorrow.  Nonprofits & Activism
# 40864  Logan Paul Vlogs  Suicide: Be Here Tomorrow.  Nonprofits & Activism
# 40865  Logan Paul Vlogs  Suicide: Be Here Tomorrow.  Nonprofits & Activism
#
#       publish_month  publish_year trending_date     views
# 40858       January          2018    2018-01-25   8041970
# 40859       January          2018    2018-01-26  15808339
# 40860       January          2018    2018-01-27  19092511
# 40861       January          2018    2018-01-28  21104436
# 40862       January          2018    2018-01-29  22387656
# 40863       January          2018    2018-01-30  23164093
# 40864       January          2018    2018-01-31  23742391
# 40865       January          2018    2018-02-01  24286474

# %%
df.loc[(df['genre']=='Music'),['video_id','channel_title','title','genre','publish_time','publish_month','publish_year','trending_date','views']]
# Out:
#           video_id     channel_title
# 26038  5E4ZBSInqUU        marshmello  \
# 26039  n1WpP7iowLc        EminemVEVO
# 26040  e_7zHm7GsYc      Hunter Hayes
# 26041  zZ9FciUx6gs        Nickelback
# 26042  PaJCFHXcWmM            U2VEVO
# ...            ...               ...
# 32505  2in8XqiElwc  NickiMinajAtVEVO
# 32506  n_W54baizX8      Daddy Yankee
# 32507  pcJo0tIWybY           SZAVEVO
# 32508  7UoP9ABJXGE      Dan And Shay
# 32509  ju_inUnrLc4  FifthHarmonyVEVO
#
#                                                    title  genre publish_time
# 26038         Marshmello - Blocks (Official Music Video)  Music   2017-11-13  \
# 26039         Eminem - Walk On Water (Audio) ft. Beyoncé  Music   2017-11-10
# 26040  Hunter Hayes - You Should Be Loved (Part One O...  Music   2017-11-13
# 26041  Nickelback - The Betrayal Act III [Official Vi...  Music   2017-11-13
# 26042                                  U2 - The Blackout  Music   2017-11-13
# ...                                                  ...    ...          ...
# 32505         Nicki Minaj - Chun-Li (Live on SNL / 2018)  Music   2018-05-20
# 32506               Daddy Yankee - Hielo (Video Oficial)  Music   2018-05-18
# 32507    SZA - Garden (Say It Like Dat) (Official Video)  Music   2018-05-18
# 32508            Dan + Shay - Speechless (Wedding Video)  Music   2018-05-18
# 32509              Fifth Harmony - Don't Say You Love Me  Music   2018-05-18
#
#       publish_month  publish_year trending_date     views
# 26038      November          2017    2017-11-14    687582
# 26039      November          2017    2017-11-14  17158531
# 26040      November          2017    2017-11-14     13917
# 26041      November          2017    2017-11-14     57169
# 26042      November          2017    2017-11-14     60506
# ...             ...           ...           ...       ...
# 32505           May          2018    2018-06-14   4945185
# 32506           May          2018    2018-06-14  41803845
# 32507           May          2018    2018-06-14   6004782
# 32508           May          2018    2018-06-14   5534278
# 32509           May          2018    2018-06-14  23502572
#
# [6472 rows x 9 columns]

# %%
df['days_to_trend'] = (df['trending_date'] - df['publish_time']).dt.days

# %%
music_df = df[df['genre'] == 'Music']

# %%
first_5_days_df = music_df[music_df['days_to_trend'] <= 5]

# %%
first_5_days_views = first_5_days_df.groupby('video_id')['views'].mean()

# %%
first_5_days_views
# Out:
# video_id
# -2aVkGcI7ZA     1668643.5
# -35jibKqbEo     1082718.2
# -5aaJJQFvOg      562232.0
# -9rdDeWzvsU      296615.0
# -BDImdAfodA      770754.5
#                   ...
# zi_6oaQyckM     4478349.8
# zkG4Xpz6t68    14852405.2
# zkrq7Kpd1so     1648886.0
# zvjqcoiOPbE      672352.5
# zwEn-ambXLw      127245.0
# Name: views, Length: 765, dtype: float64
